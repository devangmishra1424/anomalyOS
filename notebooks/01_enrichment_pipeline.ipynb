# %% [markdown]
# # Data Enrichment Pipeline
#
# This notebook demonstrates the data enrichment pipeline for anomaly detection datasets.

# %%
import sys
sys.path.insert(0, '..')

from src.enrichment import EnrichmentPipeline, DataEnricher
import logging

logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

# %% [markdown]
# ## Load Raw Data

# %%
# Load raw data from source
raw_data = [
    {'id': '001', 'image_path': '/data/sample1.jpg', 'category': 'bottle'},
    {'id': '002', 'image_path': '/data/sample2.jpg', 'category': 'carpet'}
]

print(f"Loaded {len(raw_data)} items")

# %% [markdown]
# ## Run Enrichment Pipeline

# %%
pipeline = EnrichmentPipeline()
enriched_data = pipeline.process(raw_data)

print(f"Enriched {len(enriched_data)} items")
print(f"Sample enriched item: {enriched_data[0]}")
