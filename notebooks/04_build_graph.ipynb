# %% [markdown]
# # Build Knowledge Graph
#
# Construct knowledge graph from anomaly data.

# %%
import sys
sys.path.insert(0, '..')

from src.graph import KnowledgeGraph, GraphBuilder
import logging

logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

# %% [markdown]
# ## Initialize Graph Builder

# %%
builder = GraphBuilder()
print("GraphBuilder initialized")

# %% [markdown]
# ## Build Graph from Data

# %%
# Sample anomaly data
anomalies = [
    {'id': 'anom_001', 'type': 'scratch', 'category': 'bottle', 'severity': 'high'},
    {'id': 'anom_002', 'type': 'crack', 'category': 'carpet', 'severity': 'medium'}
]

builder.build_from_data(anomalies)
print(f"Built graph with {len(anomalies)} nodes")

builder.kg.save_graph()
print("Graph saved")
